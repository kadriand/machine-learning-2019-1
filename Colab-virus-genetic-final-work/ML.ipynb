# %%
# !pip install biopython
# !cp "/content/drive/My Drive/Colab Notebooks/Sequences" .
# !cp "/content/drive/My Drive/Colab Notebooks/sequence(1).gb" .
# Out:
# ...
#      |████████████████████████████████| 2.2MB 5.2MB/s
# ...

# %%
#Execute this cell to install your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from Bio import Entrez
from Bio import SeqIO
import numpy as np
#Entrez.api_key = "MyAPIkey"
Entrez.email = "samezquitan@unal.edu.co"
#handle = Entrez.esearch(db='Nucleotide',term='viruses',filters= ':')
#record = Entrez.read(handle)

gb_file = "sequence(1).gb"
record = SeqIO.parse(open(gb_file,"r"), "genbank")
record_dict = SeqIO.to_dict(record)
for i in record_dict.keys():
    #print(record_dict[i].annotations.keys())
    print(record_dict[i].seq[:10],record_dict[i].annotations['taxonomy'][-2])
    #print(record_dict[i].seq[:10])
'''Estoy siguiendo el tutorial pero por ser esta una cuenta gratis de cocalc no permite acceder a las cosas que sean online, como el fetching de información de databases.
Descargue 500 viruses para trabajar, es mas sencillo comenzar así.'''

# %%
#estas son las referencias que estoy usando

# con lo que acabo de hacer ya se puede empezar a trabajar

#https://warwick.ac.uk/fac/sci/moac/people/students/peter_cock/python/genbank/
#    http://biopython.org/DIST/docs/tutorial/Tutorial.html#htoc1
#        http://biopython.org/DIST/docs/tutorial/Tutorial.html#chapter:entrez

# %% [markdown]
# # Para leer el pickle

# %%
import pickle
import pandas as pd

# %%
read_file=open("Sequences","rb")
new_families,new_seqs,new_type_seq=pickle.load(read_file)

# %%
d={"Families":new_families,"Sequence":new_seqs,"Type sequence":new_type_seq}
df=pd.DataFrame(data=d)

# %%
filter_family=df.groupby("Families").count().sort_values(by="Sequence",ascending=False)[:9].index

# %%
df.groupby("Families").count().sort_values(by="Sequence",ascending=False)[:9].sum()/len(df)
# Out:
# Sequence         0.895643
# Type sequence    0.895643
# dtype: float64

# %%
df.groupby("Families").count().sort_values(by="Sequence",ascending=False)[:9]
# Out:
#                   Sequence  Type sequence
# Families
# Retroviridae         20271          20271
# Orthomyxoviridae     17342          17342
# Flaviviridae          3932           3932
# Herpesviridae         1580           1580
# Paramyxoviridae       1173           1173
# Caliciviridae         1012           1012
# Reoviridae             695            695
# Papillomaviridae       556            556
# Picornaviridae         488            488

# %%
df_2=df[df["Families"].isin(filter_family)].reset_index(drop=True)

# %%
df_2.groupby(["Families","Type sequence"]).count()
# Out:
#                                 Sequence
# Families         Type sequence
# Caliciviridae    RNA                 972
#                  mRNA                 38
#                  ss-RNA                2
# Flaviviridae     DNA                 392
#                  RNA                3074
#                  ds-RNA                1
#                  mRNA                345
#                  ss-RNA              120
# Herpesviridae    DNA                1524
#                  RNA                   4
#                  mRNA                 52
# Orthomyxoviridae DNA                   3
#                  RNA                 319
#                  cRNA              16818
#                  mRNA                202
# Papillomaviridae DNA                 549
#                  RNA                   2
#                  mRNA                  5
# Paramyxoviridae  DNA                 118
#                  RNA                 318
#                  cRNA                466
# ...

# %%
df_2.groupby(["Families","Type sequence"]).count()
# Out:
#                                 Sequence
# Families         Type sequence
# Caliciviridae    RNA                 972
#                  mRNA                 38
#                  ss-RNA                2
# Flaviviridae     DNA                 392
#                  RNA                3074
#                  ds-RNA                1
#                  mRNA                345
#                  ss-RNA              120
# Herpesviridae    DNA                1524
#                  RNA                   4
#                  mRNA                 52
# Orthomyxoviridae DNA                   3
#                  RNA                 319
#                  cRNA              16818
#                  mRNA                202
# Papillomaviridae DNA                 549
#                  RNA                   2
#                  mRNA                  5
# Paramyxoviridae  DNA                 118
#                  RNA                 318
#                  cRNA                466
# ...
