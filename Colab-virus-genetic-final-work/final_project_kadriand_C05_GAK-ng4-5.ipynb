# %%
# !pip install biopython
from Bio import Entrez
from Bio import SeqIO
import numpy as np
import pickle
import pandas as pd
from collections import Counter
import matplotlib.pylab as plt
import random
import time

dataset_name="sequences_no_short_top_fams"
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.6/dist-packages (1.74)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython) (1.16.4)

# %%
#Execute this cell to install your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Creating dataset

# %%
# !cp "/content/drive/My Drive/Colab Notebooks/gbvrlBase.seq" .
# !cp "/content/drive/My Drive/Colab Notebooks/Sequences" .
# !cp "/content/drive/My Drive/Colab Notebooks/sequence(1).gb" .

# %%
gb_file = "/content/drive/My Drive/Colab Notebooks/gbvrlBase.seq"
record = SeqIO.parse(open(gb_file,"r"), "genbank")
record_dict = SeqIO.to_dict(record)

# %%
families=[]
seqs=[]
type_seq=[]
full=[]
name=[]
for i in record_dict.keys():
    family=record_dict[i].annotations['taxonomy']
    type_molecule=record_dict[i].annotations["molecule_type"]
    if record_dict[i].features[0].qualifiers["mol_type"][0].startswith('genomic'):
        for j in family:
            if j.endswith("dae") and not j.startswith("unclassified") and not j.startswith("unassigned"):
                fam=j
                families.append(j)
                seqs.append(str(record_dict[i].seq))
                type_seq.append(type_molecule)
                full.append(record_dict[i])
                name.append(i)

# %%
out_file=open("sequences_filtered","wb")
pickle.dump((families,seqs,type_seq,name),out_file)

# %%
! cp sequences_filtered "drive/My Drive/Colab Notebooks/sequences_filtered"

# %% [markdown]
# # Reading dataset

# %%
! cp "drive/My Drive/Colab Notebooks/sequences_filtered" sequences_filtered

# %%
read_file=open("sequences_filtered","rb")
new_families,new_seqs,new_type_seq,names=pickle.load(read_file)
d={"Families":new_families,"Sequence":new_seqs,"Type sequence":new_type_seq,"Names":names}
df=pd.DataFrame(data=d)
len(df)
# Out:
# 32201

# %%
df[df["Type sequence"]=="RNA"].groupby("Families").count().sort_values(by="Sequence",ascending=False)
df.groupby("Type sequence").count()
# Out:
#                Families  Sequence  Names
# Type sequence
# DNA               19586     19586  19586
# RNA               11983     11983  11983
# ds-RNA               64        64     64
# ss-DNA                3         3      3
# ss-RNA              565       565    565

# %%
acum=0
aux=0
for i in df.groupby(["Families"]).count().sort_values(by=["Sequence","Type sequence"],ascending=False,axis=0)["Sequence"].values:
    acum+=i
    if acum/32201 > 0.9:
        break
    else:
        aux+=1
print("The families needed to take the {}% of the data is {}".format(round(acum/32201*100,2),aux))
df.groupby(["Families"]).count().sort_values(by=["Sequence","Type sequence"],ascending=False,axis=0)[:14]
# Out:
# The families needed to take the 90.7% of the data is 14
#                   Sequence  Type sequence  Names
# Families
# Retroviridae         19066          19066  19066
# Flaviviridae          3580           3580   3580
# Herpesviridae         1516           1516   1516
# Caliciviridae          974            974    974
# Papillomaviridae       548            548    548
# Reoviridae             535            535    535
# Paramyxoviridae        440            440    440
# Picornaviridae         437            437    437
# Poxviridae             373            373    373
# Rhabdoviridae          323            323    323
# Orthomyxoviridae       313            313    313
# Hepadnaviridae         287            287    287
# Adenoviridae           281            281    281
# Togaviridae            270            270    270

# %%
df["Length"]=df["Sequence"].apply(len) # get the length of each sequence
df["Letters"]=df["Sequence"].apply(set).apply(sorted) #get the letters that each sequence has and put it in an array
def inspeccion(x):
  result=True
  si_son=["A","C","T","N","G"]
  for i in range(len(x)):
    if x[i] not in si_son:
      return not result
    else:
      continue
  return result

def is_N_in(x):
  result=False
  for i in range(len(x)):
    if x[i]=="N":
      return not result
    else:
      continue
  return result

df_new=df[(~df["Letters"].apply(is_N_in)) & (df["Letters"].apply(inspeccion))].reset_index(drop=True)

# %%
lower_bound=100
acum=0
aux=0
total=df_new[df_new["Length"]>lower_bound].groupby(["Families","Type sequence"]).count().sum()[0]
for i in df_new[df_new["Length"]>lower_bound].groupby(["Families"]).count().sort_values(by=["Sequence","Type sequence"],ascending=False,axis=0)["Sequence"].values:
    acum+=i
    if acum/total > 0.9:
        break
    else:
        aux+=1
print("The families needed to take the {}% of the data is {}".format(round(acum/total*100,2),aux+1))
df_new[df_new["Length"]>lower_bound].groupby(["Families"]).count().sort_values(by=["Sequence","Type sequence"],ascending=False,axis=0)[:aux].sum()
# Out:
# The families needed to take the 90.11% of the data is 14
# Sequence         26282
# Type sequence    26282
# Names            26282
# Length           26282
# Letters          26282
# dtype: int64

# %%
families_size=aux+1
df_valid_length=df_new[df_new["Length"]>lower_bound].reset_index(drop=True)
frequent_families = df_valid_length.groupby('Families').count().sort_values(by=["Sequence","Type sequence"],ascending=False,axis=0)[:families_size]['Sequence'].keys()

df_viruses =df_valid_length[df_valid_length['Families'].isin(frequent_families)]
print(f"The new dataset consists of {families_size} families and covers {round(acum/total*100,2)}% of the data")
df_viruses.groupby(["Families"]).count()
# Out:
# The new dataset consists of 14 families and covers 90.11% of the data
#                   Sequence  Type sequence  Names  Length  Letters
# Families
# Caliciviridae          884            884    884     884      884
# Flaviviridae          3269           3269   3269    3269     3269
# Hepadnaviridae         268            268    268     268      268
# Herpesviridae         1274           1274   1274    1274     1274
# Orthomyxoviridae       294            294    294     294      294
# Papillomaviridae       529            529    529     529      529
# Paramyxoviridae        419            419    419     419      419
# Picornaviridae         329            329    329     329      329
# Potyviridae            246            246    246     246      246
# Poxviridae             368            368    368     368      368
# Reoviridae             479            479    479     479      479
# Retroviridae         17610          17610  17610   17610    17610
# Rhabdoviridae          305            305    305     305      305
# Togaviridae            254            254    254     254      254

# %%
sequences = df_viruses["Sequence"]
families = df_viruses["Families"]

# %%
dataset_file=open(dataset_name,"wb")
pickle.dump((sequences, families),dataset_file)
# !cp "$dataset_name" "drive/My Drive/Colab Notebooks/final/$dataset_name"

# %% [markdown]
# # Utils

# %%
import time
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC, SVC

complexity=0.05

# %%
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots(figsize = (10,10))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm

# %%
project_path = f"drive/My Drive/Colab Notebooks/final"
dataset_path = f"{project_path}/{dataset_name}"
read_ds_file=open(dataset_path,"rb")
(sequences, families) = pickle.load(read_ds_file)

# %%
sequences.str.len().sort_values(ascending = False)[:15]
# Out:
# 16629    230278
# 21843    229354
# 23690    223666
# 15696    190289
# 24617    186986
# 22362    185578
# 9196     184439
# 20935    177923
# 21424    172281
# 4891     162519
# 4895     162493
# 4877     162492
# 4886     162490
# 4887     162490
# 4876     162488
# Name: Sequence, dtype: int64

# %% [markdown]
# # Classification _n-grams_

# %% [markdown]
# ### Making the dataset

# %%
seqs_train, seqs_test, fams_train, fams_test = train_test_split(sequences, families, test_size=0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize

cv = CountVectorizer(analyzer="char", ngram_range=(4,5), lowercase=True)
cv.fit(sequences)
len(cv.get_feature_names())
# Out:
# 1280

# %%
seqs_train_vect = cv.transform(seqs_train)
seqs_train_vect = normalize(seqs_train_vect, norm='l1', axis=1).toarray()

# %%
seqs_test_vect = cv.transform(seqs_test)
seqs_test_vect = normalize(seqs_test_vect, norm='l1', axis=1).toarray()

# %%
# Size of test an train datasets
print(f"train: dataset {seqs_train_vect.shape}")
print(f"test: dataset {seqs_test_vect.shape}")
# Out:
# train: dataset (21222, 5376)
# test: dataset (5306, 5376)

# %%
seqs_train=seqs_train.reset_index(drop=True)
fams_train=fams_train.reset_index(drop=True)

svm_ng_path = f"{project_path}/svm_gak_dataset.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump((seqs_train_vect, seqs_test_vect, fams_train, fams_test), svm_ng_file)

# %% [markdown]
# ### Training the model

# %%
def gak_similarity(seq1, seq2):
  seq1_nz = seq1.nonzero()[0]
  seq2_nz = seq2.nonzero()[0]
  
  nzi= seq1_nz if len(seq1_nz) < len(seq2_nz) else seq2_nz
  short_seq = seq1 if len(seq1_nz) < len(seq2_nz) else seq2
  large_seq = seq2 if len(seq1_nz) < len(seq2_nz) else seq1
  
  result=0
  for i in nzi:
    if large_seq[i] is not 0:
      result+= short_seq[i]*large_seq[i]
  return result


def gak_kernel(X, Y):
    """Another function to return the gram_matrix,
    which is needed in SVC's kernel or fit
    """
    gram_matrix = np.zeros((X.shape[0], Y.shape[0]))
    for i, x in enumerate(X):
        for j, y in enumerate(Y):
            gram_matrix[i, j] = gak_similarity(x, y)
    return gram_matrix

# %%
partitions = 40

support_vectors = []
partition_size = int(len(seqs_train) / partitions)
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  partition_sequences = seqs_train_vect[start:end]
  partition_families = fams_train[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  support_vectors = np.concatenate((support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")
# Out:
# partition 1 / 40
# number of new support vectors 313 in 110.92s
# partition 2 / 40
# number of new support vectors 297 in 107.36s
# partition 3 / 40
# number of new support vectors 296 in 103.35s
# partition 4 / 40
# number of new support vectors 318 in 110.36s
# partition 5 / 40
# number of new support vectors 326 in 107.9s
# partition 6 / 40
# number of new support vectors 303 in 106.04s
# partition 7 / 40
# number of new support vectors 297 in 104.55s
# partition 8 / 40
# number of new support vectors 286 in 109.97s
# partition 9 / 40
# number of new support vectors 297 in 106.42s
# partition 10 / 40
# number of new support vectors 302 in 107.48s
# partition 11 / 40
# number of new support vectors 294 in 109.46s
# partition 12 / 40
# number of new support vectors 281 in 104.7s
# partition 13 / 40
# number of new support vectors 290 in 108.19s
# partition 14 / 40
# number of new support vectors 315 in 112.12s
# partition 15 / 40
# number of new support vectors 276 in 102.28s
# partition 16 / 40
# number of new support vectors 314 in 104.49s
# partition 17 / 40
# number of new support vectors 285 in 107.33s
# partition 18 / 40
# number of new support vectors 311 in 105.44s
# partition 19 / 40
# number of new support vectors 278 in 110.97s
# partition 20 / 40
# number of new support vectors 322 in 107.96s
# partition 21 / 40
# number of new support vectors 293 in 106.91s
# partition 22 / 40
# number of new support vectors 293 in 106.69s
# partition 23 / 40
# number of new support vectors 301 in 107.71s
# partition 24 / 40
# number of new support vectors 264 in 108.34s
# partition 25 / 40
# number of new support vectors 311 in 108.16s
# partition 26 / 40
# number of new support vectors 288 in 110.86s
# partition 27 / 40
# number of new support vectors 270 in 107.08s
# partition 28 / 40
# number of new support vectors 317 in 110.3s
# partition 29 / 40
# number of new support vectors 310 in 107.25s
# partition 30 / 40
# number of new support vectors 312 in 97.7s
# partition 31 / 40
# number of new support vectors 298 in 104.09s
# partition 32 / 40
# number of new support vectors 301 in 109.17s
# partition 33 / 40
# number of new support vectors 303 in 109.88s
# partition 34 / 40
# number of new support vectors 295 in 105.91s
# partition 35 / 40
# number of new support vectors 293 in 110.28s
# partition 36 / 40
# number of new support vectors 279 in 107.7s
# partition 37 / 40
# number of new support vectors 300 in 106.77s
# partition 38 / 40
# number of new support vectors 266 in 108.07s
# partition 39 / 40
# number of new support vectors 294 in 110.83s
# partition 40 / 40
# number of new support vectors 320 in 105.92s

# %%
svm_ng_path = f"{project_path}/svm_gak_sv1.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(support_vectors, svm_ng_file)

# %%
svm_ng_path = f"{project_path}/svm_gak_sv1.pkl"
svm_ng_file = open(svm_ng_path,"rb"))
support_vectors = pickle.load(svm_ng_file)

# %%
partitions = 20

last_support_vectors = support_vectors.astype(int)
random.shuffle(last_support_vectors)

next_seqs = seqs_train_vect[last_support_vectors]
next_fams = fams_train[last_support_vectors]

next_support_vectors =[]
partition_size = int(len(next_seqs) / partitions)
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  
  partition_sequences = next_seqs[start:end]
  partition_families = next_fams[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")
# Out:
# partition 1 / 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-121669d0d774> in <module>()
#      18   print(f"partition {partition+1} / {partitions}")
#      19   svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
# ---> 20   svm.fit(partition_sequences, partition_families)
#      21   next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
#      22   elapsed_time = time.time() - start_time
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     207
#     208         seed = rnd.randint(np.iinfo('i').max)
# --> 209         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     210         # see comment on the other call to np.iinfo in this file
#     211
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     247             # TODO: add keyword copy to copy on demand
#     248             self.__Xfit = X
# --> 249             X = self._compute_kernel(X)
#     250
#     251             if X.shape[0] != X.shape[1]:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py in _compute_kernel(self, X)
#     374             # in the case of precomputed kernel given as a function, we
#     375             # have to compute explicitly the kernel matrix
# --> 376             kernel = self.kernel(X, self.__Xfit)
#     377             if sp.issparse(kernel):
#     378                 kernel = kernel.toarray()
#
# <ipython-input-20-4d374ea103b9> in gak_kernel(X, Y)
#      21     for i, x in enumerate(X):
#      22         for j, y in enumerate(Y):
# ---> 23             gram_matrix[i, j] = gak_similarity(x, y)
#      24     return gram_matrix
#
# <ipython-input-20-4d374ea103b9> in gak_similarity(seq1, seq2)
#       9   result=0
#      10   for i in nzi:
# ---> 11     if large_seq[i] is not 0:
#      12       result+= short_seq[i]*large_seq[i]
#      13   return result
#
# KeyboardInterrupt:

# %%
svm_ng_path = f"{project_path}/svm_gak_sv2.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(next_support_vectors, svm_ng_file)

# %%
svm_ng_path = f"{project_path}/svm_gak_sv2.pkl"
svm_ng_file = open(svm_ng_path,"rb")
next_support_vectors = pickle.load(svm_ng_file)

# %%
partitions = 12

last_support_vectors = next_support_vectors.astype(int)
random.shuffle(last_support_vectors)

next_seqs = seqs_train_vect[last_support_vectors]
next_fams = fams_train[last_support_vectors]

next_support_vectors =[]
partition_size = int(len(next_seqs) / partitions)
print(f"partition size: {partition_size}")
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  
  partition_sequences = next_seqs[start:end]
  partition_families = next_fams[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")


svm_ng_path = f"{project_path}/svm_gak_sv3.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(next_support_vectors, svm_ng_file)
# Out:
# partition size: 572
# partition 1 / 12
# number of new support vectors 312 in 126.75s
# partition 2 / 12
# number of new support vectors 312 in 134.98s
# partition 3 / 12
# number of new support vectors 333 in 125.79s
# partition 4 / 12
# number of new support vectors 338 in 127.66s
# partition 5 / 12
# number of new support vectors 333 in 124.25s
# partition 6 / 12
# number of new support vectors 308 in 130.16s
# partition 7 / 12
# number of new support vectors 337 in 121.01s
# partition 8 / 12
# number of new support vectors 308 in 127.62s
# partition 9 / 12
# number of new support vectors 327 in 126.07s
# partition 10 / 12
# number of new support vectors 315 in 129.58s
# partition 11 / 12
# number of new support vectors 324 in 128.32s
# partition 12 / 12
# number of new support vectors 304 in 126.44s

# %%
partitions = 6

last_support_vectors = next_support_vectors.astype(int)
random.shuffle(last_support_vectors)

next_seqs = seqs_train_vect[last_support_vectors]
next_fams = fams_train[last_support_vectors]

next_support_vectors =[]
partition_size = int(len(next_seqs) / partitions)
print(f"partition size: {partition_size}")
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  
  partition_sequences = next_seqs[start:end]
  partition_families = next_fams[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")


svm_ng_path = f"{project_path}/svm_gak_sv4.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(next_support_vectors, svm_ng_file)
# Out:
# partition size: 641
# partition 1 / 6
# number of new support vectors 364 in 169.53s
# partition 2 / 6
# number of new support vectors 366 in 161.08s
# partition 3 / 6
# number of new support vectors 354 in 157.9s
# partition 4 / 6
# number of new support vectors 351 in 157.04s
# partition 5 / 6
# number of new support vectors 391 in 155.21s
# partition 6 / 6
# number of new support vectors 366 in 162.39s

# %%
partitions = 3

last_support_vectors = next_support_vectors.astype(int)
random.shuffle(last_support_vectors)

next_seqs = seqs_train_vect[last_support_vectors]
next_fams = fams_train[last_support_vectors]

next_support_vectors =[]
partition_size = int(len(next_seqs) / partitions)
print(f"partition size: {partition_size}")
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  
  partition_sequences = next_seqs[start:end]
  partition_families = next_fams[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")


print(f"number of resulting support vectors {len(next_support_vectors)} in {round(elapsed_time,2)}s")
svm_ng_path = f"{project_path}/svm_gak_sv5.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(next_support_vectors, svm_ng_file)
# Out:
# partition size: 730
# partition 1 / 3
# number of new support vectors 397 in 203.77s
# partition 2 / 3
# number of new support vectors 388 in 204.87s
# partition 3 / 3
# number of new support vectors 407 in 211.07s

# %%
partitions = 1

last_support_vectors = next_support_vectors.astype(int)
random.shuffle(last_support_vectors)

next_seqs = seqs_train_vect[last_support_vectors]
next_fams = fams_train[last_support_vectors]

next_support_vectors =[]
partition_size = int(len(next_seqs) / partitions)
print(f"partition size: {partition_size}")
for partition in range(partitions):
  start_time = time.time()
  start = partition*partition_size
  end = (partition+1)*partition_size
  
  partition_sequences = next_seqs[start:end]
  partition_families = next_fams[start:end]
  print(f"partition {partition+1} / {partitions}")
  svm = SVC(C=complexity, kernel=gak_kernel, max_iter=5000, tol=1e-5)
  svm.fit(partition_sequences, partition_families)
  next_support_vectors = np.concatenate((next_support_vectors, svm.support_), axis=0)
  elapsed_time = time.time() - start_time
  print(f"number of new support vectors {len(svm.support_)} in {round(elapsed_time,2)}s")


print(f"number of resulting support vectors {len(next_support_vectors)} in {round(elapsed_time,2)}s")
# Out:
# partition size: 1192
# partition 1 / 1
# number of new support vectors 630 in 562.04s
# number of resulting support vectors 630 in 562.04s

# %%
svm_ng_path = f"{project_path}/svm_gak_sv_final_nn.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(next_support_vectors, svm_ng_file)

# %% [markdown]
# ### Saving the model

# %%
svm_ng_path = f"{project_path}/svm_ng_gak.pkl"
svm_ng_file = open(svm_ng_path,"wb")
pickle.dump(svm, svm_ng_file)

# %% [markdown]
# ### Classifying

# %%
# train_prediction = svm.predict(seqs_train_vect)
test_prediction= svm.predict(seqs_test_vect)

# %%
print(classification_report(fams_test, test_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    Caliciviridae       0.00      0.00      0.00       169
#     Flaviviridae       0.00      0.00      0.00       617
#   Hepadnaviridae       0.00      0.00      0.00        56
#    Herpesviridae       0.00      0.00      0.00       253
# Orthomyxoviridae       0.00      0.00      0.00        60
# Papillomaviridae       0.00      0.00      0.00       101
#  Paramyxoviridae       0.00      0.00      0.00        83
#   Picornaviridae       0.00      0.00      0.00        77
#      Potyviridae       0.00      0.00      0.00        55
#       Poxviridae       0.00      0.00      0.00        63
#       Reoviridae       0.00      0.00      0.00        99
#     Retroviridae       0.67      1.00      0.80      3559
#    Rhabdoviridae       0.00      0.00      0.00        64
#      Togaviridae       0.00      0.00      0.00        50
#
#         accuracy                           0.67      5306
#        macro avg       0.05      0.07      0.06      5306
#     weighted avg       0.45      0.67      0.54      5306
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(classification_report(fams_train, train_prediction))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                   precision    recall  f1-score   support
#
#    Caliciviridae       0.00      0.00      0.00       715
#     Flaviviridae       0.00      0.00      0.00      2652
#   Hepadnaviridae       0.00      0.00      0.00       212
#    Herpesviridae       0.00      0.00      0.00      1021
# Orthomyxoviridae       0.00      0.00      0.00       234
# Papillomaviridae       0.00      0.00      0.00       428
#  Paramyxoviridae       0.00      0.00      0.00       336
#   Picornaviridae       0.00      0.00      0.00       252
#      Potyviridae       0.00      0.00      0.00       191
#       Poxviridae       0.00      0.00      0.00       305
#       Reoviridae       0.00      0.00      0.00       380
#     Retroviridae       0.66      1.00      0.80     14051
#    Rhabdoviridae       0.00      0.00      0.00       241
#      Togaviridae       0.00      0.00      0.00       204
#
#         accuracy                           0.66     21222
#        macro avg       0.05      0.07      0.06     21222
#     weighted avg       0.44      0.66      0.53     21222

# %%
# Plot non-normalized confusion matrix
frequent_families=families.unique()
cm = plot_confusion_matrix(fams_test, test_prediction, classes=np.asarray(frequent_families), title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# Creating the n-grams of size 4 to 6

# %% [markdown]
# # Making the dataset for handling long sequences

# %%
sequence_max_size = 5000
filter= sequences.apply(lambda s: len(s) <= sequence_max_size)
sequences_ohs=sequences[filter].reset_index(drop=True)
families_ohs=families[filter].reset_index(drop=True)

print(f"Number of sequences of size < {sequence_max_size} : {len(families_ohs)}")
oh_fraction = len(families_ohs)/len(families)
print(f"{round(oh_fraction*100,2)}% of the original set")
# Out:
# Number of sequences of size < 5000 : 24875
# 93.77% of the original set

# %%
sequence_max_size = 5000
filter= sequences.apply(lambda s: len(s) > sequence_max_size)
sequences_ohl=sequences[filter].reset_index(drop=True)
families_ohl=families[filter].reset_index(drop=True)
print(f"Number of sequences of size > {sequence_max_size} : {len(families_ohl)}")
oh_fraction = len(families_ohl)/len(families)
print(f"{round(oh_fraction*100,2)}% of the original set")
# Out:
# Number of sequences of size > 5000 : 1653
# 6.23% of the original set

# %%
long_sequences=[]
long_sequences_families=[]
for s, sequence in enumerate(sequences_ohl):
  sub_sequences = [sequence[i:i+sequence_max_size] for i in range(0, len(sequence), sequence_max_size)]
  long_sequences.extend(sub_sequences)
  long_sequences_families.extend([families_ohl[s]]*len(sub_sequences))

print(f"Long sequences chunks to append : {len(long_sequences_families)}")
families_oh = families_ohs.append(pd.Series(long_sequences_families), ignore_index=True)
sequences_oh = sequences_ohs.append(pd.Series(long_sequences), ignore_index=True)
print(f"New dataset size : {len(sequences_oh)}")
# Out:
# Long sequences chunks to append : 5727
# New dataset size : 30602

# %%
families_oh.value_counts()
# Out:
# Retroviridae        18876
# Flaviviridae         3353
# Poxviridae           2298
# Herpesviridae        1809
# Caliciviridae         904
# Papillomaviridae      597
# Reoviridae            479
# Paramyxoviridae       456
# Picornaviridae        375
# Rhabdoviridae         322
# Togaviridae           297
# Orthomyxoviridae      294
# Potyviridae           274
# Hepadnaviridae        268
# dtype: int64

# %% [markdown]
# # Classification _one-hot_

# %% [markdown]
# ### Training the model

# %%
from sklearn.preprocessing import LabelBinarizer
import gc

linear_svm = []
encoded_sequences = []
sequences_ohs = []
families_ohs = []
sequences_ohl = []
families_ohl = []
long_sequences = []
long_sequences_families = []
seqs_train, seqs_test, fams_train, fams_test = ([], [], [], [])
gc.collect()

nuc_binarizer = LabelBinarizer()
nuc_binarizer.fit(["C","G","T","A"])
nuc_binarizer.classes_
# Out:
# array(['A', 'C', 'G', 'T'], dtype='<U1')

# %%
encoded_sequences = np.zeros((len(sequences_oh), sequence_max_size,4))
for s, sequence in enumerate(sequences_oh):
  encoded_sequences[s][:len(sequence)] = nuc_binarizer.transform(list(sequence))

dims = encoded_sequences.shape
encoded_sequences = encoded_sequences.reshape(dims[0],dims[1]*dims[2])

# %%
seqs_train, seqs_test, fams_train, fams_test = train_test_split(encoded_sequences, families_oh, test_size=0.2)
print(f"training size : {len(seqs_train)}")
print(f"test size : {len(seqs_test)}")
# Out:
# trainin size : 24481
# trainin size : 6121

# %%
linear_svm = LinearSVC(C=complexity, max_iter=5000, tol=1e-5)
linear_svm.fit(seqs_train, fams_train)
# Out:
# LinearSVC(C=0.05, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=5000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=1e-05,
#           verbose=0)

# %% [markdown]
# ### Saving the model

# %%
svm_oh_path = f"{project_path}/svm_oh.pkl"
svm_oh_file = open(svm_oh_path,"wb")
pickle.dump((sequences, families), svm_oh_file)

# %% [markdown]
# ### Classifying

# %%
train_prediction = linear_svm.predict(seqs_train)
test_prediction= linear_svm.predict(seqs_test)

# %%
print(classification_report(fams_test, test_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    Caliciviridae       0.94      0.92      0.93       169
#     Flaviviridae       0.91      0.92      0.92       665
#   Hepadnaviridae       0.93      0.88      0.91        49
#    Herpesviridae       0.70      0.65      0.67       316
# Orthomyxoviridae       0.92      0.80      0.85        59
# Papillomaviridae       0.81      0.79      0.80       106
#  Paramyxoviridae       0.81      0.77      0.79        90
#   Picornaviridae       0.71      0.68      0.70        76
#      Potyviridae       0.68      0.53      0.59        57
#       Poxviridae       0.80      0.79      0.80       473
#       Reoviridae       0.89      0.81      0.85       105
#     Retroviridae       0.96      0.98      0.97      3836
#    Rhabdoviridae       0.98      0.78      0.87        77
#      Togaviridae       0.83      0.93      0.88        43
#
#         accuracy                           0.92      6121
#        macro avg       0.85      0.80      0.82      6121
#     weighted avg       0.91      0.92      0.92      6121

# %%
print(classification_report(fams_train, train_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    Caliciviridae       1.00      1.00      1.00       735
#     Flaviviridae       1.00      1.00      1.00      2688
#   Hepadnaviridae       1.00      1.00      1.00       219
#    Herpesviridae       1.00      1.00      1.00      1493
# Orthomyxoviridae       1.00      1.00      1.00       235
# Papillomaviridae       1.00      1.00      1.00       491
#  Paramyxoviridae       1.00      1.00      1.00       366
#   Picornaviridae       1.00      1.00      1.00       299
#      Potyviridae       1.00      1.00      1.00       217
#       Poxviridae       1.00      1.00      1.00      1825
#       Reoviridae       1.00      1.00      1.00       374
#     Retroviridae       1.00      1.00      1.00     15040
#    Rhabdoviridae       1.00      1.00      1.00       245
#      Togaviridae       1.00      1.00      1.00       254
#
#         accuracy                           1.00     24481
#        macro avg       1.00      1.00      1.00     24481
#     weighted avg       1.00      1.00      1.00     24481

# %%
# Plot non-normalized confusion matrix
frequent_families=families_oh.unique()
cm = plot_confusion_matrix(fams_test, test_prediction, classes=np.asarray(frequent_families), title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # Classification _ordinal_

# %% [markdown]
# ### Training the model

# %%
import gc
from sklearn.preprocessing import LabelEncoder

linear_svm = []
encoded_sequences = []
sequences_ohs = []
families_ohs = []
sequences_ohl = []
families_ohl = []
long_sequences = []
long_sequences_families = []
seqs_train, seqs_test, fams_train, fams_test = ([], [], [], [])
gc.collect()

nuc_encoder = LabelEncoder()
nuc_encoder.fit(["A", "C", "G", "T"])
nuc_encoder.classes_
# Out:
# array(['A', 'C', 'G', 'T'], dtype='<U1')

# %%
encoded_sequences = np.zeros((len(sequences_oh), sequence_max_size))
for s, sequence in enumerate(sequences_oh):
  encoded_sequences[s][:len(sequence)] = nuc_encoder.transform(list(sequence))

# %%
seqs_train, seqs_test, fams_train, fams_test = train_test_split(encoded_sequences, families_oh, test_size=0.2)
print(f"training size : {len(seqs_train)}")
print(f"test size : {len(seqs_test)}")
# Out:
# trainin size : 24481
# trainin size : 6121

# %%
linear_svm = LinearSVC(C=complexity, max_iter=5000, tol=1e-5)
linear_svm.fit(seqs_train, fams_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=0.05, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=5000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=1e-05,
#           verbose=0)

# %% [markdown]
# ### Saving the model

# %%
svm_ie_path = f"{project_path}/svm_ie.pkl"
svm_ie_file = open(svm_ie_path,"wb")
pickle.dump((sequences, families), svm_ie_file)

# %% [markdown]
# ### Classifying

# %%
train_prediction = linear_svm.predict(seqs_train)
test_prediction= linear_svm.predict(seqs_test)

# %%
print(classification_report(fams_test, test_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    Caliciviridae       0.91      0.87      0.89       180
#     Flaviviridae       0.83      0.88      0.85       681
#   Hepadnaviridae       0.77      0.80      0.79        46
#    Herpesviridae       0.57      0.52      0.54       357
# Orthomyxoviridae       0.83      0.90      0.86        67
# Papillomaviridae       0.74      0.64      0.69       117
#  Paramyxoviridae       0.76      0.72      0.74        94
#   Picornaviridae       0.59      0.53      0.56        83
#      Potyviridae       0.45      0.40      0.42        53
#       Poxviridae       0.70      0.63      0.66       466
#       Reoviridae       0.75      0.77      0.76        96
#     Retroviridae       0.93      0.94      0.93      3756
#    Rhabdoviridae       0.86      0.92      0.89        64
#      Togaviridae       0.78      0.84      0.81        61
#
#         accuracy                           0.86      6121
#        macro avg       0.75      0.74      0.74      6121
#     weighted avg       0.85      0.86      0.86      6121

# %%
print(classification_report(fams_train, train_prediction))
# Out:
#                   precision    recall  f1-score   support
#
#    Caliciviridae       1.00      0.99      1.00       724
#     Flaviviridae       0.94      0.95      0.95      2672
#   Hepadnaviridae       1.00      0.99      0.99       222
#    Herpesviridae       0.99      0.94      0.96      1452
# Orthomyxoviridae       1.00      1.00      1.00       227
# Papillomaviridae       1.00      0.96      0.98       480
#  Paramyxoviridae       1.00      0.96      0.98       362
#   Picornaviridae       1.00      0.94      0.97       292
#      Potyviridae       1.00      0.98      0.99       221
#       Poxviridae       1.00      0.98      0.99      1832
#       Reoviridae       1.00      1.00      1.00       383
#     Retroviridae       0.98      0.99      0.99     15120
#    Rhabdoviridae       1.00      0.99      1.00       258
#      Togaviridae       1.00      1.00      1.00       236
#
#         accuracy                           0.98     24481
#        macro avg       0.99      0.98      0.98     24481
#     weighted avg       0.98      0.98      0.98     24481

# %%
# Plot non-normalized confusion matrix
frequent_families=families_oh.unique()
cm = plot_confusion_matrix(fams_test, test_prediction, classes=np.asarray(frequent_families), title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
