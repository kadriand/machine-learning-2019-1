# %%
import re

# %%
re.escape(r'(6Z,9Z)-octadecadienoic acid[c]')
# Out:
# '\\(6Z\\,9Z\\)\\-octadecadienoic\\ acid\\[c\\]'

# %%
reg=re.compile(r"\b"+re.escape("g(to")+r"\b")

# %%
reg.sub("miau", "g(to un g(to gordo g(tos")
# Out:
# 'miau un miau gordo g(tos'

# %%
i=9
i+=1
i
# Out:
# 10

# %%
x = {"1": 2, "3": 4, "4": 3, "2": 1, "01": 0}
sorted_x = sorted(x.items(), key=lambda kv: len(kv[0]), reverse=True)

# %%
sorted_x
# Out:
# [('01', 0), ('1', 2), ('3', 4), ('4', 3), ('2', 1)]
